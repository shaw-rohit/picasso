# %% [markdown]
# # Load data

# %%
import pandas as pd

data = pd.read_csv("export.csv")

print(data[:5])
# Out:
# /home/oscar/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (5,6,25,26) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    omni_id                                       artwork_name  \
# 0  9005036                     bottle rack (porte-bouteilles)
# 1  9005037  bayard refusing the presents of his hostess, i...
# 2  9005038  bust of male nude (recto); portrait sketch of ...
# 3  9005039                                           hat rack
# 4  9005040                              triumph of maximilian
#
#                        artist_full_name artist_first_name  \
# 0                        marcel duchamp            marcel
# 1  anne-louis girodet de roussy-trioson        anne-louis
# 2  anne-louis girodet de roussy-trioson        anne-louis
# 3                        marcel duchamp            marcel
# ...

# %%
data.columns.values.tolist()
# Out:
# ['omni_id',
#  'artwork_name',
#  'artist_full_name',
#  'artist_first_name',
#  'artist_last_name',
#  'date',
#  'century',
#  'source_url',
#  'image_url',
#  'collection_origins',
#  'general_type',
#  'genre',
#  'school',
#  'original_id_in_collection',
#  'palette_families',
#  'palette',
#  'pixel_counts',
#  'geocoded',
#  'media',
#  'style',
#  'dimensions',
#  'location',
#  'tag',
#  'dominant_color',
#  'dominant_color_family',
#  'description',
#  'publisher',
#  'distributable_url']

# %% [markdown]
# # Drop columns

# %%
data = data.drop(['collection_origins', 'original_id_in_collection',
           'pixel_counts', 'dimensions', 'publisher', 'distributable_url'], axis=1)

# %% [markdown]
# # Look for unknown values
# Like NaN, Unk and Unknown, nan

# %%
headers = data.columns.values.tolist()
#headers = ["style"]
import numpy as np
# these ones remove most of the data
# headers.remove('location')
# headers.remove('style')
# headers.remove('school')
# headers.remove('general_type')

subdata = data


"""
for head in headers:
    try:
        bools = (back_up_data[head] == "Unknown").tolist()
        NaN_bools = (back_up_data[head] == "NaN").tolist()        
        unk_bools = (back_up_data[head] == "Unk").tolist()        
        nan_bools = (back_up_data[head] == "nan").tolist()       
        
        print('hi')

    except:
        pass
    print(head)
    print(sum(bools))
    print(len(bools))
    
    print()
    print()
    
"""



for head in headers:
    #if data[head][0] == "Unknown":
    try:
        subdata = subdata[subdata[head] != "Unknown"]
    except:
        pass        
    
    """
    try:
        back_up_data = back_up_data[back_up_data[head] != "Unk"]
    except:
        pass
    """
    
    try:
        subdata = subdata.dropna()
    except:
        pass
    
    
print(len(subdata))
print(len(data))
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/ops.py:1167: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# 253
# 1410790

# %%
print(subdata)
# Out:
#          omni_id                                       artwork_name  \
# 1124     9006160                     plaque depicting a quail chick
# 1136     9006171                      stemless kylix (drinking cup)
# 1138     9006173                              amphora (storage jar)
# 1140     9006175  pentadrachm (coin) portraying king ptolemy i s...
# 1148     9006184                                         fish plate
# 1152     9006188                                         fish plate
# 1165     9006198                           kantharos (drinking cup)
# 1167     9006202  rhyton (drinking vessel) in the shape of a don...
# 1174     9006208   oinochoe (pitcher) in the shape of a female head
# 1178     9006212            loutrophoros (container for bath water)
# 1181     9006214                         knob-handled patera (dish)
# 1182     9006215  kantharos (wine cup) in the shape of a female ...
# 1563     9006591           portrait of dr. william mcneill whistler
# ...

# %%
subdata.to_csv('subset.csv')
